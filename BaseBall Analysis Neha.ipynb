# %%
#Name-Neha Somvanshi
#project_name- BaseBall Analysis
#Batch number- DS2307

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("baseball.csv")

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# We can see that the column names of above data are difficult to understand, we need to elaborate these column name to make it easy to understand

# %%
#Changning Column names to make it easy to understand the parameters
df.columns=['Win','Runs','At Bats','Hits','Doubles','Triples','Homeruns','Walks','Strikeouts','Stolen Bases','Runs Allowed','Earned Runs','Earned Run Average','Complete Games','Shutouts','Saves','Errors']

# %%
df
# Out:
#     Win  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 0    95   724     5575  1497      300       42       139    383         973
# 1    83   696     5467  1349      277       44       156    439        1264
# 2    81   669     5439  1395      303       29       141    533        1157
# 3    76   622     5533  1381      260       27       136    404        1231
# 4    74   689     5605  1515      289       49       151    455        1259
# 5    93   891     5509  1480      308       17       232    570        1151
# 6    87   764     5567  1397      272       19       212    554        1227
# 7    81   713     5485  1370      246       20       217    418        1331
# 8    80   644     5485  1383      278       32       167    436        1310
# 9    78   748     5640  1495      294       33       161    478        1148
# 10   88   751     5511  1419      279       32       172    503        1233
# ...

# %% [markdown]
# In this Dataset we can see that there were 29 teams had participated in the tournament,and respective other details for each team is shown

# %%
# Checking datatypes of each variables
df.dtypes
# Out:
# Win                     int64
# Runs                    int64
# At Bats                 int64
# Hits                    int64
# Doubles                 int64
# Triples                 int64
# Homeruns                int64
# Walks                   int64
# Strikeouts              int64
# Stolen Bases            int64
# Runs Allowed            int64
# Earned Runs             int64
# Earned Run Average    float64
# Complete Games          int64
# Shutouts                int64
# Saves                   int64
# Errors                  int64
# dtype: object

# %%
df.shape
# Out:
# (30, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Win                 30 non-null     int64
#  1   Runs                30 non-null     int64
#  2   At Bats             30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Homeruns            30 non-null     int64
#  7   Walks               30 non-null     int64
#  8   Strikeouts          30 non-null     int64
#  9   Stolen Bases        30 non-null     int64
#  10  Runs Allowed        30 non-null     int64
#  11  Earned Runs         30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  Complete Games      30 non-null     int64
#  14  Shutouts            30 non-null     int64
#  15  Saves               30 non-null     int64
# ...

# %%
df.nunique()
# Out:
# Win                   24
# Runs                  28
# At Bats               29
# Hits                  29
# Doubles               22
# Triples               23
# Homeruns              27
# Walks                 29
# Strikeouts            29
# Stolen Bases          27
# Runs Allowed          30
# Earned Runs           30
# Earned Run Average    30
# Complete Games         9
# Shutouts              12
# Saves                 20
# Errors                21
# dtype: int64

# %%
df.describe()
# Out:
#               Win        Runs      At Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %%
df.corr()
# Out:
#                          Win      Runs   At Bats      Hits   Doubles  \
# Win                 1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                0.430751  1.000000  0.319464  0.482856  0.560084
# At Bats            -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles             0.427797  0.560084  0.453370  0.566847  1.000000
# Triples            -0.251118 -0.070072  0.435422  0.478694  0.220490
# Homeruns            0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks               0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts          0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen Bases       -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs Allowed       -0.812952 -0.041623  0.316010  0.224324 -0.218160
# Earned Runs        -0.809435 -0.041245  0.309686  0.252489 -0.235531
# Earned Run Average -0.819600 -0.049281  0.255551  0.231172 -0.254854
# ...

# %%
df.columns
# Out:
# Index(['Win', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns',
#        'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs',
#        'Earned Run Average', 'Complete Games', 'Shutouts', 'Saves', 'Errors'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Win                   0
# Runs                  0
# At Bats               0
# Hits                  0
# Doubles               0
# Triples               0
# Homeruns              0
# Walks                 0
# Strikeouts            0
# Stolen Bases          0
# Runs Allowed          0
# Earned Runs           0
# Earned Run Average    0
# Complete Games        0
# Shutouts              0
# Saves                 0
# Errors                0
# dtype: int64

# %% [markdown]
# We can see that there is no null/empty value, data is clean

# %%
# Importing some more neccessary libraries
import seaborn as sns

# %%
#Checking correlation using Heat Map to get high and low correlated parameteres
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# We can see highly correlated values with respect to wins and other variables

# %%
sns.pairplot(x_vars=['Shutouts', 'Saves', 'Walks'], y_vars='Win', size=7, aspect=0.7, kind='reg',data=df)
plt.show()
# Out:
# C:\Users\anumy\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Checking different indicators of Winner, 1st Runner up and 2nd Runner up team
import warnings
warnings.filterwarnings("ignore")
df.loc[df['Win']== df['Win'].max()]
# Out:
#     Win  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 15  100   647     5484  1386      288       39       137    506        1267
#
#     Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average  \
# 15            69           525          478                2.94
#
#     Complete Games  Shutouts  Saves  Errors
# 15               1        15     62      96

# %%
df.loc[df['Win']== 98]
# Out:
#     Win  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 16   98   697     5631  1462      292       27       140    461        1322
#
#     Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average  \
# 16            98           596          532                3.21
#
#     Complete Games  Shutouts  Saves  Errors
# 16               0        13     54     122

# %%
df.loc[df['Win']== 97]
# Out:
#     Win  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  Strikeouts  \
# 17   97   689     5491  1341      272       30       171    567        1518
#
#     Stolen Bases  Runs Allowed  Earned Runs  Earned Run Average  \
# 17            95           608          546                3.36
#
#     Complete Games  Shutouts  Saves  Errors
# 17               6        21     48     111

# %% [markdown]
# We can see that the toppers of the tournaments have maximum 'Shutouts','Save' and 'Walks'df.plot.bar(subplots=True,figsize=(20,20))

# %%
sns.scatterplot(x='At Bats',y='Hits',data=df)
plt.show()

# %%
plt.hist(df['Win'])
plt.xlabel('Wins')
plt.ylabel('No. of Teams')
plt.show()

# %%
sns.violinplot(df['Win'],scale='count')
plt.show()

# %% [markdown]
# We can see that most of the team able to win 80-90 games

# %%
fig = plt.figure(figsize=(12, 6))

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

ax1.scatter(df['Runs Allowed'], df['Win'], c='blue')
ax1.set_title('Runs Allowed vs. Wins')
ax1.set_ylabel('Wins')
ax1.set_xlabel('Runs per Game')

ax2.scatter(df['Earned Runs'], df['Win'], c='red')
ax2.set_title('Earned Runs vs. Wins')
ax2.set_xlabel('Runs Allowed per Game')

plt.show()

# %% [markdown]
# We can see that Runs Allowed and Earned Runs should be less inorder to be a winner

# %%
#Checking for outliers using box plot
df.plot(kind='box',subplots=True,layout=(3,6))
plt.show()

# %% [markdown]
# We can see that a few outliers are present which we have to remove

# %%
#Removing outliers using z score
from scipy.stats import zscore
z_score=np.abs(zscore(df))
z_score
# Out:
#          Win      Runs   At Bats      Hits   Doubles   Triples  Homeruns  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
print(df.shape)
thresold=3
baseball=df[(z_score<3).all(axis=1)]
baseball.shape
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# We can see that outliers are removed

# %%
#Separating the input and output variables
x=baseball.drop(columns=['Win'])
y=baseball[['Win']]

# %%
#Checking for skewness
x.skew()
# Out:
# Runs                 -0.215364
# At Bats               0.169573
# Hits                  0.783772
# Doubles              -0.335304
# Triples               0.090124
# Homeruns              0.450862
# Walks                 0.151193
# Strikeouts           -0.233815
# Stolen Bases          0.494966
# Runs Allowed          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Games        0.854980
# Shutouts              0.526943
# Saves                 0.627480
# Errors                0.840271
# dtype: float64

# %%
#Removing the positive  and negative skewness using log and square funtcions respectively
for index in x.skew().index:
    if x.skew().loc[index]>0.5:
        x[index]=np.log1p(x[index])
    if x.skew().loc[index]<-0.5:
        x[index]=np.square(x[index])

# %%
# Again Checking for skewness
x.skew()
# Out:
# Runs                 -0.215364
# At Bats               0.169573
# Hits                  0.732868
# Doubles              -0.335304
# Triples               0.090124
# Homeruns              0.450862
# Walks                 0.151193
# Strikeouts           -0.233815
# Stolen Bases          0.494966
# Runs Allowed          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Games       -0.275681
# Shutouts             -0.116970
# Saves                 0.109983
# Errors                0.537982
# dtype: float64

# %%
y.skew()
# Out:
# Win    0.119013
# dtype: float64

# %% [markdown]
# # In this data set we can see that there is linear/continuos data hence we use regression method to train and predict the variables

# %%
#Importing some neccessary libraries 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
#Checking for best random state which give best r2 score for various training techniques used to get best prediction
# Defining a function to check for best random state and r2 score.
def maxr2_score(tec,x,y):
    max_r_score=0
    for r_state in range(42,100):
        train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = r_state,test_size=0.20)
        tec.fit(train_x,train_y)
        pred = tec.predict(test_x)
        temp=r2_score(test_y,pred)
        if temp>max_r_score:
            max_r_score=temp
            final_r_state=r_state
    print("max r2 score is : ",max_r_score, 'corresponding to random state: ',final_r_state,)

# %%
#Importing various methods from libraries
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn import svm
from sklearn.svm import SVR
import warnings
warnings.filterwarnings("ignore")

# %%
LR=LinearRegression()
maxr2_score(LR,x,y)
# Out:
# max r2 score is :  0.8490054459207285 corresponding to random state:  73

# %%
DT=DecisionTreeRegressor()
maxr2_score(DT,x,y)
# Out:
# max r2 score is :  0.7198161142027584 corresponding to random state:  97

# %%
RF=RandomForestRegressor()
maxr2_score(RF,x,y)
# Out:
# max r2 score is :  0.7645264504339885 corresponding to random state:  46

# %%
KN=KNeighborsRegressor()
maxr2_score(KN,x,y)
# Out:
# max r2 score is :  0.7544084056646871 corresponding to random state:  46

# %%
GB=GradientBoostingRegressor()
maxr2_score(GB,x,y)
# Out:
# max r2 score is :  0.7903489287959526 corresponding to random state:  47

# %%
AB=AdaBoostRegressor()
maxr2_score(AB,x,y)
# Out:
# max r2 score is :  0.8172528649310191 corresponding to random state:  48

# %% [markdown]
# We can see the r2 score using different techniques, and Decision Tree is giving maximum r2 score

# %%
#Using Grid search CV for best parameters
DT=DecisionTreeRegressor()
parameters = {'criterion':['mae','mse']}
clf = GridSearchCV(DT,parameters, cv=10)
clf.fit(x,y)
clf.best_params_
# Out:
# {'criterion': 'mse'}

# %%
DT=DecisionTreeRegressor(criterion='mae')
maxr2_score(DT,x,y)
# Out:
# max r2 score is :  0.9224326292789512 corresponding to random state:  99

# %% [markdown]
# We can see that we are getting best r2 score using Decision Tree Regression

# %%
#Saving our final model using Random Forest Regression method
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state=99,test_size=0.20)
DT.fit(train_x,train_y)
pred=DT.predict(test_x)

# %%
#Saving final model using joblib
import joblib 
  

joblib.dump(DT, 'DT_baseball.pkl')
# Out:
# ['DT_baseball.pkl']

# %% [markdown]
# This is the best and final model we have saved
